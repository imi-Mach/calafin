# %% [markdown]
# # Analysis

# %%
# import modules
import os           # reading path
import pandas as pd # formating data into dataframe
import datetime as dt     # data rangings


# this ensures that Pandas won't add newline characters 
# to fit the output of a dataframe in the terminal 
# (code is not functionally important)
pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# # Helper Functions
#
# Here is where I define any functions I created

# %%
def remove_char_from_columns(df, char):
    columns = list(df.columns)
    for i, column in enumerate(columns):
        if char in column:
            columns[i] = "".join(column.split(char))

    df.columns = columns

# %% [markdown]
# ## Extract data from csv in '/data' folder
#
# ## Testing
# This code should be tested for the following cases:
# 1. Data directory is empty.
# 2. Folders are in the data directory.
# 3. Invalid file name formats {only underscores, no underscores, missing file extension, missing name}.
#
# ### Todo:
# * wrap code in a function or factory pattern so that the account map can generalize to different companies (i.e Chase, Discovery, etc).

# %%
# should read path from environment variables
dataPath = r"C:\Users\maxim\Work\financials\data"

# create list of files/folders in data directory
file_names = os.listdir(dataPath)

# account id's are map to the files that contain their transaction data
# NB: id's are given to be small and not likely to change in the future (many reads, rarely any writes)
acc_map = {}

# iterate through the files and match files that are csv's to an id
for file_name in file_names:
    # seperate the file name (i.e "file.txt") from its extension (i.e ["file", ".txt"]) safely (using os.path)
    split_tup = os.path.splitext(file_name)
    # pretext is the name before the "." and the extension (i.e ".txt")
    pretext = split_tup[0]
    # postext is the "." and extension (everything but the file's name)
    posttext = split_tup[1]

    # only consider files matching the extension ".CSV" extension (post call of `upper()` )
    if ".CSV" == posttext.upper():
        # chase accounts follow the pattern: <id>_<date>_<optional dates>.CSV
        # NB: this split depends on the file convention of your company
        id = pretext.split("_")[0]
        # list initialization if new id, otherwise appen filename to exisint id.
        if id in acc_map:
            acc_map[id].append(file_name)
        else:
            acc_map[id] = [file_name]

# checkings and savings accounts are seperated by the "id" in the filename

# %% [markdown]
# ## Data Frame Creation
#
# Using Pandas, each account will have it's dataframe

# %%
df_map = {}
for k, file_names in acc_map.items():
    df_list = []
    for file_name in file_names:
        df_list.append(pd.read_csv(os.path.join(dataPath, file_name)))

    # line of code that merges
    df_map[k] = pd.concat(df_list)
    remove_char_from_columns(df_map[k], " ")
    print(df_map[k])
# Out:
#    TransactionDate    PostDate                Description               Category        Type  Amount  Memo
# 0       08/12/2022  08/12/2022   Payment Thank You-Mobile                    NaN     Payment  201.45   NaN
# 1       08/10/2022  08/12/2022   TABATA NOODLE RESTAURANT           Food & Drink        Sale  -21.42   NaN
# 2       08/09/2022  08/10/2022              CHIPOTLE 2964           Food & Drink        Sale  -13.99   NaN
# 3       08/08/2022  08/09/2022         SQ *2 BROS 9TH AVE           Food & Drink        Sale   -6.00   NaN
# 4       08/07/2022  08/08/2022       DD DOORDASH GUACTIME           Food & Drink        Sale  -19.22   NaN
# 5       08/07/2022  08/07/2022          DOORDASH DASHPASS           Food & Drink        Sale   -4.99   NaN
# 6       08/05/2022  08/07/2022            SNACK* SONG TEA           Food & Drink        Sale   -9.35   NaN
# 7       08/05/2022  08/07/2022             Steam Purchase          Entertainment        Sale  -11.99   NaN
# 8       08/05/2022  08/07/2022              CHIPOTLE 2964           Food & Drink        Sale  -11.65   NaN
# 9       08/04/2022  08/05/2022               TERRA MARKET              Groceries        Sale  -21.88   NaN
# 10      08/04/2022  08/05/2022      BIG APPLE MEAT MARKET              Groceries        Sale  -18.27   NaN
# 11      08/04/2022  08/05/2022      BIG APPLE MEAT MARKET              Groceries        Sale   -4.89   NaN
# 12      08/04/2022  08/05/2022     MANHATTAN PLAZA WINERY           Food & Drink        Sale  -48.98   NaN
# 13      08/03/2022  08/04/2022        SQ *VIVI BUBBLE TEA           Food & Drink        Sale   -6.26   NaN
# 14      08/04/2022  08/04/2022  STEAMGAMES.COM 4259522985          Entertainment        Sale  -11.99   NaN
# 15      08/02/2022  08/02/2022   Payment Thank You-Mobile                    NaN     Payment  416.83   NaN
# 16      08/02/2022  08/02/2022  STEAMGAMES.COM 4259522985          Entertainment        Sale  -11.99   NaN
# 17      07/31/2022  08/01/2022       DD DOORDASH GUACTIME           Food & Drink        Sale  -25.70   NaN
# 18      07/28/2022  07/31/2022                     ANTOYA           Food & Drink        Sale -141.22   NaN
# 19      07/29/2022  07/31/2022           SHAKE SHACK 1101           Food & Drink        Sale  -12.83   NaN
# 20      07/30/2022  07/31/2022   TST* SBE - CITIZENS GO -           Food & Drink        Sale -185.61   NaN
# 21      07/30/2022  07/31/2022        WHOLEFDS BPK #10578              Groceries        Sale   -2.29   NaN
# 22      07/30/2022  07/31/2022      BIG APPLE MEAT MARKET              Groceries        Sale  -49.18   NaN
# 23      07/29/2022  07/29/2022   Payment Thank You-Mobile                    NaN     Payment  334.74   NaN
# 24      07/25/2022  07/26/2022     BEST BUY      00010280               Shopping        Sale  -27.19   NaN
# 25      07/25/2022  07/26/2022     BEST BUY      00010280               Shopping      Return   21.75   NaN
# 26      07/23/2022  07/25/2022         THE HOME DEPOT 947                   Home        Sale  -11.16   NaN
# 27      07/23/2022  07/24/2022        NORDSTROM RACK #651               Shopping        Sale   -8.50   NaN
# 28      07/23/2022  07/24/2022     TARGET        00012245               Shopping        Sale -155.05   NaN
# 29      07/22/2022  07/24/2022             MTA*NYCT PAYGO                 Travel        Sale   -2.75   NaN
# 30      07/23/2022  07/24/2022          TRADER JOE'S #614              Groceries        Sale   -6.48   NaN
# 31      07/24/2022  07/24/2022  TST* PARIS BAGUETTE - CHI           Food & Drink        Sale  -15.20   NaN
# 32      07/23/2022  07/24/2022   Payment Thank You-Mobile                    NaN     Payment  689.89   NaN
# 33      07/21/2022  07/24/2022             MTA*NYCT PAYGO                 Travel        Sale   -2.75   NaN
# 34      07/23/2022  07/24/2022          COSTCO WHSE #0322               Shopping        Sale -127.41   NaN
# 35      07/21/2022  07/22/2022        WHOLEFDS BPK #10578              Groceries        Sale   -5.45   NaN
# 36      07/21/2022  07/22/2022  TST* OBAO - 222 E 53rd St           Food & Drink        Sale -148.22   NaN
# 37      07/17/2022  07/19/2022        Muji - Times Square               Shopping        Sale  -33.86   NaN
# 38      07/17/2022  07/19/2022               TERRA MARKET              Groceries        Sale  -76.68   NaN
# 39      07/16/2022  07/18/2022     BEST BUY      00010280               Shopping        Sale  -27.18   NaN
# 40      07/17/2022  07/18/2022        WHOLEFDS BPK #10578              Groceries        Sale -134.03   NaN
# 41      07/17/2022  07/18/2022         DUANE READE #14111      Health & Wellness        Sale  -14.99   NaN
# 42      07/16/2022  07/18/2022     BEST BUY      00010280               Shopping        Sale -348.38   NaN
# 43      07/16/2022  07/17/2022          REDEMPTION CREDIT     Fees & Adjustments  Adjustment  186.06   NaN
# 44      07/15/2022  07/17/2022        CVS/PHARMACY #02435      Health & Wellness        Sale  -21.89   NaN
# 45      07/16/2022  07/17/2022   Payment Thank You-Mobile                    NaN     Payment  421.89   NaN
# 46      07/14/2022  07/17/2022      STARBUCKS STORE 56450           Food & Drink        Sale   -4.30   NaN
# 47      07/15/2022  07/17/2022          SQ *IN COMMON NYC           Food & Drink        Sale  -60.97   NaN
# 48      07/14/2022  07/15/2022      SQ *ABOUT TIME COFFEE  Professional Services        Sale  -23.63   NaN
# 49      07/13/2022  07/14/2022        IKEA ELIZABETH REST           Food & Drink        Sale   -2.00   NaN
# 50      07/12/2022  07/14/2022           NEWSLINK 31 MAIR               Shopping        Sale   -9.07   NaN
# 51      07/13/2022  07/14/2022     TARGET        00033852               Shopping        Sale -113.55   NaN
# 52      07/12/2022  07/13/2022              CHIPOTLE 2964           Food & Drink        Sale  -11.43   NaN
# 53      07/12/2022  07/13/2022     TARGET        00033852               Shopping        Sale  -42.95   NaN
# 54      07/12/2022  07/13/2022       CELLULAR SALES NY-ET               Shopping        Sale  -27.21   NaN
# 55      07/12/2022  07/13/2022     NYC TAXI 1246 12460010                 Travel        Sale  -20.05   NaN
#            Details                                        PostingDate  Description              Amount     Type  Balance  CheckorSlip#
# DEBIT   08/12/2022         Payment to Chase card ending in 8960 08/12      -201.45           ACCT_XFER  8664.95      NaN           NaN
# CREDIT  08/12/2022  VENMO            CASHOUT                    PP...       384.56          ACH_CREDIT  8866.40      NaN           NaN
# CREDIT  08/12/2022  ERNST & YOUNG US DIRECT DEP                 PP...      6239.35          ACH_CREDIT  8481.84      NaN           NaN
# DEBIT   08/05/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  2242.49      NaN           NaN
# DEBIT   08/05/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  2245.24      NaN           NaN
# DEBIT   08/04/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  2247.99      NaN           NaN
# DEBIT   08/04/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  2250.74      NaN           NaN
# DEBIT   08/04/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  2253.49      NaN           NaN
# DEBIT   08/02/2022         Payment to Chase card ending in 8960 08/02      -416.83           ACCT_XFER  2256.24      NaN           NaN
# DEBIT   08/01/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  2673.07      NaN           NaN
# DEBIT   08/01/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  2675.82      NaN           NaN
# DEBIT   08/01/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  2678.57      NaN           NaN
# DEBIT   07/29/2022         Payment to Chase card ending in 8960 07/29      -334.74           ACCT_XFER  2681.32      NaN           NaN
# DEBIT   07/29/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  3016.06      NaN           NaN
# CREDIT  07/29/2022  ERNST & YOUNG US DIRECT DEP                 PP...       754.68          ACH_CREDIT  3018.81      NaN           NaN
# DEBIT   07/26/2022                             NON-CHASE ATM FEE-WITH        -3.00     FEE_TRANSACTION  2264.13      NaN           NaN
# DEBIT   07/26/2022  NON-CHASE ATM WITHDRAW               982014  0...       -22.75                 ATM  2267.13      NaN           NaN
# DEBIT   07/26/2022  NJT RAIL MY-TIX 973-378-6339 NJ              0...       -13.25          DEBIT_CARD  2289.88      NaN           NaN
# DEBIT   07/25/2022         Payment to Chase card ending in 8960 07/25      -689.89           ACCT_XFER  2303.13      NaN           NaN
# DEBIT   07/25/2022  NJT RAIL MY-TIX 973-378-6339 NJ              0...       -13.25          DEBIT_CARD  2993.02      NaN           NaN
# DEBIT   07/22/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  3006.27      NaN           NaN
# DEBIT   07/18/2022         Payment to Chase card ending in 8960 07/18      -421.89           ACCT_XFER  3009.02      NaN           NaN
# DEBIT   07/18/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  3430.91      NaN           NaN
# DEBIT   07/18/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  3433.66      NaN           NaN
# DEBIT   07/18/2022  MTA*NYCT PAYGO NEW YORK NY                   0...        -2.75          DEBIT_CARD  3436.41      NaN           NaN
# CREDIT  07/18/2022    Zelle payment from ALEXANDER LOPEZ BACmoxbxcapz        37.45  PARTNERFI_TO_CHASE  3439.16      NaN           NaN

# %% [markdown]
# ## Analysis
#
# Simple Analysis.
#
# Todo:
#
# Helper function to convert the columns to the correct types (this function might be called earlier)

# %%
date_range = (dt.datetime(2002,7,15), dt.datetime.today())

credit_df = df_map['Chase8960']

credit_df['TransactionDate'] = credit_df['TransactionDate'].astype('datetime64[ns]')

credit_expenses = credit_df[credit_df.Amount < 0]
credit_expenses = credit_expenses[credit_expenses.TransactionDate > date_range[0]]

print(credit_expenses[['Amount']].sum())
print(credit_expenses.groupby(['Category']).sum())
print(credit_expenses)
print(credit_expenses.sort_values(['Amount'])[credit_expenses.Category == 'Shopping'])
# Out:
# Amount   -2122.03
# dtype: float64
#                        Amount  Memo
# Category
# Entertainment          -35.97   0.0
# Food & Drink          -749.34   0.0
# Groceries             -319.15   0.0
# Health & Wellness      -36.88   0.0
# Home                   -11.16   0.0
# Professional Services  -23.63   0.0
# Shopping              -920.35   0.0
# Travel                 -25.55   0.0
#    TransactionDate    PostDate                Description               Category  Type  Amount  Memo
# 1       2022-08-10  08/12/2022   TABATA NOODLE RESTAURANT           Food & Drink  Sale  -21.42   NaN
# 2       2022-08-09  08/10/2022              CHIPOTLE 2964           Food & Drink  Sale  -13.99   NaN
# 3       2022-08-08  08/09/2022         SQ *2 BROS 9TH AVE           Food & Drink  Sale   -6.00   NaN
# 4       2022-08-07  08/08/2022       DD DOORDASH GUACTIME           Food & Drink  Sale  -19.22   NaN
# 5       2022-08-07  08/07/2022          DOORDASH DASHPASS           Food & Drink  Sale   -4.99   NaN
# 6       2022-08-05  08/07/2022            SNACK* SONG TEA           Food & Drink  Sale   -9.35   NaN
# 7       2022-08-05  08/07/2022             Steam Purchase          Entertainment  Sale  -11.99   NaN
# 8       2022-08-05  08/07/2022              CHIPOTLE 2964           Food & Drink  Sale  -11.65   NaN
# 9       2022-08-04  08/05/2022               TERRA MARKET              Groceries  Sale  -21.88   NaN
# 10      2022-08-04  08/05/2022      BIG APPLE MEAT MARKET              Groceries  Sale  -18.27   NaN
# 11      2022-08-04  08/05/2022      BIG APPLE MEAT MARKET              Groceries  Sale   -4.89   NaN
# 12      2022-08-04  08/05/2022     MANHATTAN PLAZA WINERY           Food & Drink  Sale  -48.98   NaN
# 13      2022-08-03  08/04/2022        SQ *VIVI BUBBLE TEA           Food & Drink  Sale   -6.26   NaN
# 14      2022-08-04  08/04/2022  STEAMGAMES.COM 4259522985          Entertainment  Sale  -11.99   NaN
# 16      2022-08-02  08/02/2022  STEAMGAMES.COM 4259522985          Entertainment  Sale  -11.99   NaN
# 17      2022-07-31  08/01/2022       DD DOORDASH GUACTIME           Food & Drink  Sale  -25.70   NaN
# 18      2022-07-28  07/31/2022                     ANTOYA           Food & Drink  Sale -141.22   NaN
# 19      2022-07-29  07/31/2022           SHAKE SHACK 1101           Food & Drink  Sale  -12.83   NaN
# 20      2022-07-30  07/31/2022   TST* SBE - CITIZENS GO -           Food & Drink  Sale -185.61   NaN
# 21      2022-07-30  07/31/2022        WHOLEFDS BPK #10578              Groceries  Sale   -2.29   NaN
# 22      2022-07-30  07/31/2022      BIG APPLE MEAT MARKET              Groceries  Sale  -49.18   NaN
# 24      2022-07-25  07/26/2022     BEST BUY      00010280               Shopping  Sale  -27.19   NaN
# 26      2022-07-23  07/25/2022         THE HOME DEPOT 947                   Home  Sale  -11.16   NaN
# 27      2022-07-23  07/24/2022        NORDSTROM RACK #651               Shopping  Sale   -8.50   NaN
# 28      2022-07-23  07/24/2022     TARGET        00012245               Shopping  Sale -155.05   NaN
# 29      2022-07-22  07/24/2022             MTA*NYCT PAYGO                 Travel  Sale   -2.75   NaN
# 30      2022-07-23  07/24/2022          TRADER JOE'S #614              Groceries  Sale   -6.48   NaN
# 31      2022-07-24  07/24/2022  TST* PARIS BAGUETTE - CHI           Food & Drink  Sale  -15.20   NaN
# 33      2022-07-21  07/24/2022             MTA*NYCT PAYGO                 Travel  Sale   -2.75   NaN
# 34      2022-07-23  07/24/2022          COSTCO WHSE #0322               Shopping  Sale -127.41   NaN
# 35      2022-07-21  07/22/2022        WHOLEFDS BPK #10578              Groceries  Sale   -5.45   NaN
# 36      2022-07-21  07/22/2022  TST* OBAO - 222 E 53rd St           Food & Drink  Sale -148.22   NaN
# 37      2022-07-17  07/19/2022        Muji - Times Square               Shopping  Sale  -33.86   NaN
# 38      2022-07-17  07/19/2022               TERRA MARKET              Groceries  Sale  -76.68   NaN
# 39      2022-07-16  07/18/2022     BEST BUY      00010280               Shopping  Sale  -27.18   NaN
# 40      2022-07-17  07/18/2022        WHOLEFDS BPK #10578              Groceries  Sale -134.03   NaN
# 41      2022-07-17  07/18/2022         DUANE READE #14111      Health & Wellness  Sale  -14.99   NaN
# 42      2022-07-16  07/18/2022     BEST BUY      00010280               Shopping  Sale -348.38   NaN
# 44      2022-07-15  07/17/2022        CVS/PHARMACY #02435      Health & Wellness  Sale  -21.89   NaN
# 46      2022-07-14  07/17/2022      STARBUCKS STORE 56450           Food & Drink  Sale   -4.30   NaN
# 47      2022-07-15  07/17/2022          SQ *IN COMMON NYC           Food & Drink  Sale  -60.97   NaN
# 48      2022-07-14  07/15/2022      SQ *ABOUT TIME COFFEE  Professional Services  Sale  -23.63   NaN
# 49      2022-07-13  07/14/2022        IKEA ELIZABETH REST           Food & Drink  Sale   -2.00   NaN
# 50      2022-07-12  07/14/2022           NEWSLINK 31 MAIR               Shopping  Sale   -9.07   NaN
# 51      2022-07-13  07/14/2022     TARGET        00033852               Shopping  Sale -113.55   NaN
# 52      2022-07-12  07/13/2022              CHIPOTLE 2964           Food & Drink  Sale  -11.43   NaN
# 53      2022-07-12  07/13/2022     TARGET        00033852               Shopping  Sale  -42.95   NaN
# 54      2022-07-12  07/13/2022       CELLULAR SALES NY-ET               Shopping  Sale  -27.21   NaN
# 55      2022-07-12  07/13/2022     NYC TAXI 1246 12460010                 Travel  Sale  -20.05   NaN
#    TransactionDate    PostDate             Description  Category  Type  Amount  Memo
# 42      2022-07-16  07/18/2022  BEST BUY      00010280  Shopping  Sale -348.38   NaN
# 28      2022-07-23  07/24/2022  TARGET        00012245  Shopping  Sale -155.05   NaN
# 34      2022-07-23  07/24/2022       COSTCO WHSE #0322  Shopping  Sale -127.41   NaN
# 51      2022-07-13  07/14/2022  TARGET        00033852  Shopping  Sale -113.55   NaN
# 53      2022-07-12  07/13/2022  TARGET        00033852  Shopping  Sale  -42.95   NaN
# 37      2022-07-17  07/19/2022     Muji - Times Square  Shopping  Sale  -33.86   NaN
# 54      2022-07-12  07/13/2022    CELLULAR SALES NY-ET  Shopping  Sale  -27.21   NaN
# 24      2022-07-25  07/26/2022  BEST BUY      00010280  Shopping  Sale  -27.19   NaN
# 39      2022-07-16  07/18/2022  BEST BUY      00010280  Shopping  Sale  -27.18   NaN
# 50      2022-07-12  07/14/2022        NEWSLINK 31 MAIR  Shopping  Sale   -9.07   NaN
# 27      2022-07-23  07/24/2022     NORDSTROM RACK #651  Shopping  Sale   -8.50   NaN
# C:\Users\maxim\AppData\Local\Temp\ipykernel_29464\4058529355.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(credit_expenses.sort_values(['Amount'])[credit_expenses.Category == 'Shopping'])
